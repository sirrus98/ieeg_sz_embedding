# %%
# %load_ext autoreload
# %autoreload 2
import os
from os.path import join as ospj
import pickle

import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from tqdm.notebook import tqdm
from einops import rearrange

from config import CONFIG
from model_v5 import MultivarWav2Vec2
from model_wrapper import ModelV3WrapperWithQueue
from dataset import SzDatasetRegsFull
from model_config import MODEL_CONFIG
from torch.utils.data import DataLoader
import statsmodels.formula.api as smf
import torch

import umap
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import AgglomerativeClustering

from utils import plot_iEEG_data

mpl.style.use('figures.mplstyle')
MM_TO_IN = 1/25.4
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
fname = os.path.join(CONFIG.data_dir, "all_sz_coords_data_spatiotemporal_regs_10s.pkl")
with open(fname, 'rb') as f:
    signals, coords, regs, indices = pickle.load(f)

# %%
subsample = 0.8

# %%
new_size = int(MODEL_CONFIG.channel_buffer_size * subsample)
print(new_size)
for sig, coord, reg in zip(signals, coords, regs):
    # subsample
    if subsample != 1:
        # randomly select indices
        selected_idx = torch.randint(low=0, high=sig.shape[0], size=(int(len(sig) * subsample),), generator=torch.Generator().manual_seed(41))
        print(selected_idx)
        print(len(sig))
        print(int(len(sig) * subsample))

        raise SystemExit
# Out:
# 120
# tensor([52, 67, 64, 50, 68, 67, 39, 77, 77,  3, 58, 29, 74, 46, 93, 43, 32, 34,
#          8, 30, 92, 19, 75, 45, 46, 36, 17, 88, 70, 65, 64, 87, 57, 28, 26, 11,
#         62, 17, 13, 85, 31, 18, 47, 44, 22, 18,  3, 37, 48, 78, 80, 39, 30, 77,
#          8, 19, 45, 69, 70, 90, 34, 10, 21, 60, 47, 66,  3, 41, 13, 79, 27, 44,
#         76, 52, 26])
# 94
# 75
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /home1/p/pattnaik/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3441: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
